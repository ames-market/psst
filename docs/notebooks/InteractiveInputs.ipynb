# %% [markdown]
# # Interactive Inputs

# %%
import ipywidgets as ipyw

# %%
from psst.case.generator import Generator
from psst.case.generator import GeneratorColumnView as GeneratorView
from psst.case.generator import GeneratorCostView

import ipywidgets as ipyw

# %%
g = Generator(maximum_real_power=100)

# %%
g.nsegments = 3

# %%
gv = GeneratorView(g)
gcv = GeneratorCostView(g)

# %%
ipyw.HBox(children=[gv, gcv])
# Out:
# HBox(children=(GeneratorColumnView(children=(HTML(value='Generator:'), Text(value='GenCo0', description='Name'), Checkbox(value=True, description='Initial Status:'), Dropdown(description='Generation Type:', options=('COAL', 'NATURALGAS', 'WIND'), value='COAL'), BoundedFloatText(value=100.0, description='Capacity (MW):', max=10000000000.0), BoundedFloatText(value=0.0, description='Minimum Generation (MW):'), BoundedFloatText(value=0.0, description='Initial Generation (MW):'), BoundedFloatText(value=0.0, description='Minimum Up Time (hr):', max=24.0), BoundedFloatText(value=0.0, description='Minimum Down Time (hr):', max=24.0), IntSlider(value=3, description='Number of Cost Curve Segments', max=50, min=2), BoundedFloatText(value=100.0, description='Ramp Up Rate (MW/hr):'), BoundedFloatText(value=100.0, description='Ramp Down Rate (MW/hr):'), BoundedFloatText(value=0.0, description='Startup Time (hr):', max=24.0), BoundedFloatText(value=0.0, description='Shutdown Time (hr):', max=24.0), BoundedFloatText(value=0.0, description='No-Load Cost ($/hr):', max=10000000000.0), BoundedFloatText(value=0.0, description='Startup Cost ($/hr):', max=10000000000.0))), GeneratorCostView(children=(Figure(axes=[Axis(scale=LinearScale(max=100.0, min=0.0)), Axis(orientation='vertical', scale=LinearScale(max=50.0, min=0.0))], fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(min_width='125px'), marks=[Lines(colors=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'], interactions={'hover': 'tooltip'}, scales={'x': LinearScale(max=100.0, min=0.0), 'y': LinearScale(max=50.0, min=0.0)}, scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}}, tooltip_style={'opacity': 0.9}, x=array([   0.        ,   33.33333333,   66.66666667,  100.        ]), y=array([ 0.,  0.,  0.,  0.])), Scatter(colors=['DeepSkyBlue'], enable_move=True, interactions={'click': None}, scales={'x': LinearScale(max=100.0, min=0.0), 'y': LinearScale(max=50.0, min=0.0)}, scales_metadata={'x': {'orientation': 'horizontal', 'dimension': 'x'}, 'y': {'orientation': 'vertical', 'dimension': 'y'}, 'color': {'dimension': 'color'}, 'size': {'dimension': 'size'}, 'opacity': {'dimension': 'opacity'}, 'rotation': {'dimension': 'rotation'}, 'skew': {'dimension': 'skew'}}, tooltip_style={'opacity': 0.9}, update_on_move=True, x=array([   0.        ,   33.33333333,   66.66666667,  100.        ]), y=array([ 0.,  0.,  0.,  0.]))], scale_x=LinearScale(allow_padding=False, max=1.0, min=0.0), scale_y=LinearScale(allow_padding=False, max=1.0, min=0.0)),))))
